# %%
QPATH = "Quantlet/7-corpus-token-ident"
import sys
IN_COLAB = 'google.colab' in sys.modules

import os
if IN_COLAB:
  os.chdir(f'/content/drive/MyDrive/ColabNotebooks/IRTG/Encode_the_Qode/Encode-the-Qode/{QPATH}')

# %%
import pandas as pd

# %%
test = pd.read_csv('../../data/preprocessed/Quantlet/test_df_with_domain_20231002.csv')
val  = pd.read_csv('../../data/preprocessed/Quantlet/val_df_with_domain_20231002.csv')

# %%
test[test['type_script']=='py'].domain_ratio.describe()
# Out:
# count    94.000000
# mean      0.571883
# std       0.103933
# min       0.368000
# 25%       0.474250
# 50%       0.557500
# 75%       0.644750
# max       0.781000
# Name: domain_ratio, dtype: float64

# %%
test[test['type_script']=='r'].domain_ratio.describe()
# Out:
# count    219.000000
# mean       0.657712
# std        0.121349
# min        0.361000
# 25%        0.579000
# 50%        0.669000
# 75%        0.740000
# max        0.938000
# Name: domain_ratio, dtype: float64

# %%
test[test['type_script']=='m'].domain_ratio.describe()
# Out:
# count    148.000000
# mean       0.597189
# std        0.154920
# min        0.263000
# 25%        0.484250
# 50%        0.575000
# 75%        0.730000
# max        1.000000
# Name: domain_ratio, dtype: float64
