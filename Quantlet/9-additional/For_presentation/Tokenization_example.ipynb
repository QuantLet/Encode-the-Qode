# %%
code = ''' import sys
sys.path.append('../Create_description')

from preprocessing_utils import QuantletDataset

class QuantletDescriptionMeta(QuantletDataset):

    def __init__(self, parsed_Qs_file):
         super().__init__(parsed_Qs_file)'''

# %%
import re

# %%
code = re.sub('[^A-Za-z0-9]+', ' ', code)

# %%
code.split()
# Out:
# ['import',
#  'sys',
#  'sys',
#  'path',
#  'append',
#  'Create',
#  'description',
#  'from',
#  'preprocessing',
#  'utils',
#  'import',
#  'QuantletDataset',
#  'class',
#  'QuantletDescriptionMeta',
#  'QuantletDataset',
#  'def',
#  'init',
#  'self',
#  'parsed',
#  'Qs',
#  'file',
#  'super',
#  'init',
#  'parsed',
#  'Qs',
#  'file']

# %%
# %pip install pyflowchart

# %%
from pyflowchart import *

# %%
st = StartNode('start utils.py')
op = OperationNode('import package sys')
op2 = OperationNode('append path')
op3 = OperationNode('load QuantletDataset class from preprocessing utils')
op4 = OperationNode('declare new class that inherits from QunatletDataset')
e = EndNode('end utils.py')

st.connect(op)
op.connect(op2)
op2.connect(op3)
op3.connect(op4)
op4.connect(e)


fc = Flowchart(st)
print(fc.flowchart())
# Out:
# st0=>start: start start utils.py
# op1=>operation: import package sys
# op2=>operation: append path
# op3=>operation: load QuantletDataset class from preprocessing utils
# op4=>operation: declare new class that inherits from QunatletDataset
# e5=>end: end end utils.py
#
# st0->op1
# op1->op2
# op2->op3
# op3->op4
# op4->e5

# %%
map = {"CodeSearchNet" : 2000000, 'QuantLet' : 6000, 'Ai4Code' : 160000}

# %%
160000/2000000
# Out:
# 0.08
