# %%
import os 
import pandas as pd
from tqdm import tqdm
import numpy as np
import yaml
from datetime import datetime

# %%
PATH_TO_PARSE = '../data/QuantLet_to_parse'
FILE_TYPES = ['m', 'py', 'r', 'R', 'M'] #'ipynb',
TEST_PATH = '../data/Q_test'

# %%
# q_name, folder_name, code_script, type_script, metainfo_file
language, name = '', ''
for i, (root, directories, files) in enumerate(os.walk(PATH_TO_PARSE)):
    
    for file in files:
        language = file.split('.')[-1]
        
        if (language == 'ipynb'):
            if not os.path.exists(f"{root}/{file.replace('ipynb', 'py')}"):
                print(file)
                os.popen(f"jupyter nbconvert --to python {root}/{file}")
        else:
            continue
# Out:
# VAR_Example.ipynb
# SC Animation .ipynb
# SC Animation -checkpoint.ipynb
# fit_IV_DEJD.ipynb
# Data Preprocessing.ipynb
# Download Tiingo Data.ipynb
# table 3.ipynb
# table 3-checkpoint.ipynb
# crix_calculation.ipynb
# crix_calculation-checkpoint.ipynb
# figure 2.ipynb
# figure 6_7_8_9_10_11.ipynb
# figure 12.ipynb
# Figure 3_4_5.ipynb
# get_calibratedCopulae.ipynb
# concatenate_rh_timeseries.ipynb
# gen_MSEs_LSVs.ipynb
# figure 13.ipynb
# select_copula.ipynb
# Download Tiingo Data-checkpoint.ipynb
# Data Preprocessing-checkpoint.ipynb
# plots.ipynb
# run.ipynb
# run-Copy1.ipynb
# run-Copy2.ipynb
# run-Copy1-checkpoint.ipynb
# run-checkpoint.ipynb
# run-Copy2-checkpoint.ipynb
# plots-checkpoint.ipynb
# DEDA_2020_Sentiment-Analysis-of-Cryptocurrencies.ipynb
# Random Forest Classifier.ipynb
# Deribit_inverse_BTC_options_hedging.ipynb
# Filter sentiment.ipynb
# Legality map.ipynb
# Web scraping.ipynb
# Crpto prices.ipynb
# DEDA_Class_SS2018_Regrisk_sentiment_analysis.ipynb
# Umap on cryptopunks.ipynb
# Umap on cryptopunks-checkpoint.ipynb
# centrality_bar_chart_race.ipynb
# Weights_bar_chart_race_1_0_2.ipynb
# 21 SFM1 TS Project Xingjia Wang.ipynb
# rejected_quick_analysis.ipynb
# data_cleaning_new_complete_data.ipynb
# Density estimation.ipynb
# ARIMA_TM.ipynb
# 03_Cross validation.ipynb
# Data Preprocessing.ipynb
# Download Tiingo Data.ipynb
# table 3.ipynb
# table 3-checkpoint.ipynb
# crix_calculation.ipynb
# crix_calculation-checkpoint.ipynb
# figure 2.ipynb
# figure 6_7_8_9_10_11.ipynb
# figure 12.ipynb
# Figure 3_4_5.ipynb
# Figure 3_4_5-checkpoint.ipynb
# figure 6_7_8_9_10_11-checkpoint.ipynb
# figure 2-checkpoint.ipynb
# figure 12-checkpoint.ipynb
# Download Tiingo Data-checkpoint.ipynb
# Data Preprocessing-checkpoint.ipynb
# KEC_cluster shapes.ipynb
# some examples.ipynb
# Nasdaq _news application.ipynb
# k-expectile functions.ipynb
# Pink Noise.ipynb
# DEDA_Class_2022_HW2_311707034_DavidJheng.ipynb
# HW2_311712023_Buris_Taipei Bike.ipynb
# HW2_311707020_Inyu_Scatterplot and Maps of New Taipei City’s bike dataset.ipynb
# HW2_TracyZhou_0453946_YoubikeLocation.ipynb
# HW2_YoucefTahari_311709815_ubikes_ZhongshanDistrict.ipynb
# DEDA_Class_2022_311707016_JingXun.ipynb
# DEDA_Class_2022_410707007_Tzu-Ying.ipynb
# DEDA_MobileCluster_Buris_311712023.ipynb
# DEDA_311709815_Youcef_Clustering.ipynb
# DEDA_BondCluster_Tracy_0453946.ipynb
# DEDA_Class_2022_HW5_311707034_DavidJheng.ipynb
# HW5_311707020_Inyu_Cluster data.ipynb
# DEDA_Class_2022_311707016_JingXun.ipynb
# HW3_311707020_Inyu_Sentimental Analysis.ipynb
# DEDA_Class_2022_HW3_311707034_DavidJheng.ipynb
# Using Machine Learning To Predict The Price Of Taiwan Top 50 Tracker Fund.ipynb
# HW1_311707020_Draw a bird with big mouth (or called Toucan).ipynb
# /bin/sh: -c: line 0: syntax error near unexpected token `('
# /bin/sh: -c: line 0: `jupyter nbconvert --to python ../data/QuantLet_to_parse/DEDA_2022_NYCU/HW1/HW1_311707020_Draw a bird with big mouth (or called Toucan)/HW1_311707020_Draw a bird with big mouth (or called Toucan).ipynb'
# DEDA_Class_2022_HW1_311707034_DavidJheng.ipynb
# DEDA_RandomForest_bond_Tracy_0453946.ipynb
# DEDA_Class_2022_410707007_Tzu-Ying.ipynb
# DEDA_Class_2022_410707007_Tzu-Ying.ipynb
# DEDA_Class_2022_HW9_311707020_InyuChen.ipynb
# main.ipynb
# Fraud_Detection_UMAP.ipynb
# /bin/sh: -c: line 0: syntax error near unexpected token `('
# /bin/sh: -c: line 0: `jupyter nbconvert --to python ../data/QuantLet_to_parse/DEDA_2022_NYCU/HW5_Optional(7th Oct.)_Credit data set CART tree/DEDA_RandomForest_bond_Tracy_0453946/DEDA_RandomForest_bond_Tracy_0453946.ipynb'
# /bin/sh: -c: line 0: syntax error near unexpected token `('
# /bin/sh: -c: line 0: `jupyter nbconvert --to python ../data/QuantLet_to_parse/DEDA_2022_NYCU/HW5_Optional(7th Oct.)_Credit data set CART tree/DEDA_Class_2022_410707007_Tzu-Ying/DEDA_Class_2022_410707007_Tzu-Ying.ipynb'
# Fraud_Detection_Model_Selection.ipynb
# Fraud_Detection_EDA.ipynb
# Efficiency of cryptocurrency markets.ipynb
# Coins.ipynb
# monthly_returns.ipynb
# Crix.ipynb
# HW2(Optionl)_311707020_Inyu_Word distribution_song_we are the world.ipynb
# /bin/sh: -c: line 0: syntax error near unexpected token `('
# /bin/sh: -c: line 0: `jupyter nbconvert --to python ../data/QuantLet_to_parse/DEDA_2022_NYCU/HW2_Optional 1_Word distribution- song/HW2(Optional)_311707020_Inyu_Word distribution_song_we are the world/HW2(Optionl)_311707020_Inyu_Word distribution_song_we are the world.ipynb'
# simulation study-checkpoint.ipynb
# fetch bitcoin future data-checkpoint.ipynb
# Serial Dependency.ipynb
# sensitivity analysis.ipynb
# hedging effectiveness.ipynb
# Sanity Check.ipynb
# Basel III backtest.ipynb
# loss function analysis.ipynb
# SOSD results.ipynb
# fit copula crix brr.ipynb
# alternative way.ipynb
# kernel density estimation.ipynb
# gumbel 3.ipynb
# Gumbel mix Clayton.ipynb
# quantile denpendence analysis.ipynb
# Data Exploration.ipynb
# Gaussian Copula.ipynb
# draw results from v3 OHR using v5 data.ipynb
# fit copula 3.ipynb
# fit copula 5-Copy3.ipynb
# NIG copula.ipynb
# NIG Quantile Estimation.ipynb
# draw result cumulative return.ipynb
# Confidence Interval.ipynb
# HE confidence interval.ipynb
# coingecko fetch and cleaning.ipynb
# fit copula 5-Copy1.ipynb
# CRIX BTC CME future data cleaning.ipynb
# fetch bitcoin future data.ipynb
# fit copula 5.ipynb
# static and dynamic hedge results.ipynb
# Data Handling 2.ipynb
# Clayton Rotation.ipynb
# sample from NIG.ipynb
# draw results.ipynb
# small training size.ipynb
# multivariate NIG distribution.ipynb
# fit copula.ipynb
# fit copula btc future.ipynb
# hedging effectiveness result.ipynb
# quantile dependence analysis.ipynb
# simulation study.ipynb
# fit copula 5-Copy2.ipynb
# fit copula 2.ipynb
# compare MLE and MM.ipynb
# Cornish Fisher Approximation Error Analysis and Speed Testing.ipynb
# Dependency break point analysis.ipynb
# OHR time series plots.ipynb
# fit copula 4.ipynb
# fit copula 5-Copy4.ipynb
# fit copula btc future-checkpoint.ipynb
# sample from NIG-checkpoint.ipynb
# quantile denpendence analysis-checkpoint.ipynb
# Pink Noise-checkpoint.ipynb
# compare MLE and MM-checkpoint.ipynb
# fit copula 2-checkpoint.ipynb
# Confidence Interval-checkpoint.ipynb
# fit copula 5-Copy3-checkpoint.ipynb
# hedging effectiveness-checkpoint.ipynb
# SOSD results-checkpoint.ipynb
# kernel density estimation-checkpoint.ipynb
# Basel III backtest-checkpoint.ipynb
# Data Handling 2-checkpoint.ipynb
# sensitivity analysis-checkpoint.ipynb
# draw result cumulative return-checkpoint.ipynb
# draw results-checkpoint.ipynb
# draw results from v3 OHR using v5 data-checkpoint.ipynb
# alternative way-checkpoint.ipynb
# small training size-checkpoint.ipynb
# fit copula 3-checkpoint.ipynb
# Sanity Check-checkpoint.ipynb
# simulation study-checkpoint.ipynb
# gumbel 3-checkpoint.ipynb
# CRIX BTC CME future data cleaning-checkpoint.ipynb
# fit copula 5-Copy2-checkpoint.ipynb
# OHR time series plots-checkpoint.ipynb
# fit copula crix brr-checkpoint.ipynb
# Gumbel mix Clayton-checkpoint.ipynb
# fit copula-checkpoint.ipynb
# quantile dependence analysis-checkpoint.ipynb
# Data Exploration-checkpoint.ipynb
# HE confidence interval-checkpoint.ipynb
# fit copula 5-Copy1-checkpoint.ipynb
# multivariate NIG distribution-checkpoint.ipynb
# static and dynamic hedge results-checkpoint.ipynb
# Gaussian Copula-checkpoint.ipynb
# fit copula 4-checkpoint.ipynb
# NIG copula-checkpoint.ipynb
# Serial Dependency-checkpoint.ipynb
# Clayton Rotation-checkpoint.ipynb
# NIG Quantile Estimation-checkpoint.ipynb
# hedging effectiveness result-checkpoint.ipynb
# loss function analysis-checkpoint.ipynb
# fit copula 5-checkpoint.ipynb
# coingecko fetch and cleaning-checkpoint.ipynb
# fit copula 5-Copy4-checkpoint.ipynb
# Dependency break point analysis-checkpoint.ipynb
# Cornish Fisher Approximation Error Analysis and Speed Testing-checkpoint.ipynb
# sensitivity analysis.ipynb
# Figure 6-7-8 Scenarios.ipynb
# Table 3-4-5-6.ipynb
# Figure 9 Historical performance.ipynb
# Figure 1 Table 2 Figure 4 Labels.ipynb
# Table 7 Backtest performance.ipynb
# [NbConvertApp] WARNING | pattern '../data/QuantLet_to_parse/SC/SC_Animation/SC' matched no files
# [NbConvertApp] WARNING | pattern 'Animation' matched no files
# [NbConvertApp] WARNING | pattern '.ipynb' matched no files
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 525, in convert_notebooks
#     self.print_help()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 512, in print_help
#     print('\n'.join(self.emit_help(classes=classes)))
# BrokenPipeError: [Errno 32] Broken pipe
# Bank Cluster.ipynb
# Bike Sharing Taipei.ipynb
# Dynamic Merton  CORRECT!-Copy1.ipynb
# HestonIntegration (4)-Copy1.ipynb
# /bin/sh: -c: line 0: syntax error near unexpected token `('
# /bin/sh: -c: line 0: `jupyter nbconvert --to python ../data/QuantLet_to_parse/CRIXHEDGING/HestonIntegration (4)-Copy1.ipynb'
# ustatboot.ipynb
# ustatvar.ipynb
# semiParametricModel.ipynb
# semiParametricModel-checkpoint.ipynb
# [NbConvertApp] Converting notebook ../data/QuantLet_to_parse/VAR_Example/VAR_Example.ipynb to python
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbformat/reader.py", line 18, in parse_json
#     nb_dict = json.loads(s, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/json/__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 2 column 1 (char 1)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 541, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 506, in convert_single_notebook
#     output, resources = self.export_single_notebook(notebook_filename, resources, input_buffer=input_buffer)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 435, in export_single_notebook
#     output, resources = self.exporter.from_filename(notebook_filename, resources=resources)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 190, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 208, in from_file
#     return self.from_notebook_node(nbformat.read(file_stream, as_version=4), resources=resources, **kw)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbformat/__init__.py", line 170, in read
#     return reads(buf, as_version, capture_validation_error, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbformat/__init__.py", line 88, in reads
#     nb = reader.reads(s, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbformat/reader.py", line 72, in reads
#     nb_dict = parse_json(s, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbformat/reader.py", line 21, in parse_json
#     raise NotJSONError(("Notebook does not appear to be JSON: %r" % s)[:77] + "...") from e
# nbformat.reader.NotJSONError: Notebook does not appear to be JSON: '\n'...
# usage: jupyter-nbconvert [-h] [--debug] [--show-config] [--show-config-json]
#                          [--generate-config] [-y] [--execute] [--allow-errors]
#                          [--stdin] [--stdout] [--inplace] [--clear-output]
#                          [--no-prompt] [--no-input]
#                          [--allow-chromium-download]
#                          [--disable-chromium-sandbox] [--show-input]
#                          [--embed-images] [--log-level NbConvertApp.log_level]
#                          [--config NbConvertApp.config_file]
#                          [--to NbConvertApp.export_format]
#                          [--template TemplateExporter.template_name]
#                          [--template-file TemplateExporter.template_file]
#                          [--theme HTMLExporter.theme]
#                          [--writer NbConvertApp.writer_class]
#                          [--post NbConvertApp.postprocessor_class]
#                          [--output NbConvertApp.output_base]
#                          [--output-dir FilesWriter.build_directory]
#                          [--reveal-prefix SlidesExporter.reveal_url_prefix]
#                          [--nbformat NotebookExporter.nbformat_version]
#                          [extra_args ...]
# jupyter-nbconvert: error: argument -checkpoint.ipynb: expected one argument
# ratePlots.ipynb
# ratePlots-checkpoint.ipynb
# [NbConvertApp] Converting notebook ../data/QuantLet_to_parse/fit_IV_DEJD/fit_IV_DEJD.ipynb to python
# heckman_huberization.ipynb
# Quarterly_art_market_sales.ipynb
# NFT_data_analysis.ipynb
# residual_analysis.ipynb
# compute_index.ipynb
# simulation.ipynb
# [NbConvertApp] WARNING | pattern '../data/QuantLet_to_parse/Hedging-Cryptos-with-Bitcoin-Futures/newToQuantlet/Pynotebooks/Download' matched no files
# [NbConvertApp] WARNING | pattern 'Tiingo' matched no files
# [NbConvertApp] WARNING | pattern 'Data.ipynb' matched no files
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 525, in convert_notebooks
#     self.print_help()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 512, in print_help
#     print('\n'.join(self.emit_help(classes=classes)))
# BrokenPipeError: [Errno 32] Broken pipe
# score.ipynb
# autocorrelation_causality.ipynb
# Fake News Detection.ipynb
# FE5225_Project_Step2_retrain_model.ipynb
# FE5225_Project_Step4_calculate_sentiment_sinanews.ipynb
# FE5225_Project_Step1_Sourcedata_to_txt.ipynb
# FE5225_Project_Step3_calculate_accuracy.ipynb
# FE5225_Project_Step5_Regression for the relationship between sentiment and market.ipynb
# Combine Data.ipynb
# Dataset Spilt.ipynb
# Feature Selection.ipynb
# [NbConvertApp] WARNING | pattern '../data/QuantLet_to_parse/Hedging-Cryptos-with-Bitcoin-Futures/newToQuantlet/Pynotebooks/figures/figure' matched no files
# [NbConvertApp] WARNING | pattern '2.ipynb' matched no files
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 525, in convert_notebooks
#     self.print_help()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 512, in prin
# Modelling_Baseline_Optimized Parameter.ipynb
# Baseline(no parameters).ipynb
# MNIST Chinese Symbol_CNN.ipynb
# HMM Analysis of Heart Rate Data.ipynb
# t_help
# [NbConvertApp] WARNING | pattern '../data/QuantLet_to_parse/DEDA_RandForest/DEDA_RandForest_Credit_Solvency/Random' matched no files
# [NbConvertApp] WARNING | pattern 'Forest' matched no files
# [NbConvertApp] WARNING | pattern 'Classifier.ipynb' matched no files
# [NbConvertApp] WARNING | pattern '../data/QuantLet_to_parse/Hedging-Cryptos-with-Bitcoin-Futures/newToQuantlet/Pynotebooks/figures/figure' matched no files
# [NbConvertApp] WARNING | pattern '6_7_8_9_10_11.ipynb' matched no files
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 525, in convert_notebooks
# [NbConvertApp] WARNING | pattern '../data/QuantLet_to_parse/Hedging-Cryptos-with-Bitcoin-Futures/newToQuantlet/Pynotebooks/Data' matched no files
# [NbConvertApp] WARNING | pattern 'Preprocessing.ipynb' matched no files
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 525, in convert_notebooks
#     self.print_help()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 512, in print_help
#     print('\n'.join(self.emit_help(classes=classes)))
# BrokenPipeError: [Errno 32] Broken pipe
#     print('\n'.join(self.emit_help(classes=classes)))
# BrokenPipeError: [Errno 32] Broken pipe
#     self.print_help()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 512, in print_help
#     print('\n'.join(self.emit_help(classes=classes)))
# BrokenPipeError: [Errno 32] Broken pipe
# /bin/sh: -c: line 0: syntax error near unexpected token `('
# /bin/sh: -c: line 0: `jupyter nbconvert --to python ../data/QuantLet_to_parse/SDA_2021_NUS/SDA_2021_NUS_Credit_Card_Default_Prediction/Modelling_Baseline/Baseline(no parameters).ipynb'
# app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 525, in convert_notebooks
#     self.print_help()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 512, in print_help
#     print('\n'.join(self.emit_help(classes=classes)))
# BrokenPipeError: [Errno 32] Broken pipe
# [NbConvertApp] WARNING | pattern '../data/QuantLet_to_parse/Hedging-Cryptos-with-Bitcoin-Futures/newToQuantlet/Pynotebooks/tables/.ipynb_checkpoints/table' matched no files
# [NbConvertApp] WARNING | pattern '3-checkpoint.ipynb' matched no files
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 525, in convert_notebooks
#     self.print_help()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 512, in print_help
#     print('\n'.join(self.emit_help(classes=classes)))
# BrokenPipeError: [Errno 32] Broken pipe
# [NbConvertApp] Converting notebook ../data/QuantLet_to_parse/Hedging-Cryptos-with-Bitcoin-Futures/newToQuantlet/Pynotebooks/figures/intraday/concatenate_rh_timeseries.ipynb to python
# [NbConvertApp] WARNING | pattern '../data/QuantLet_to_parse/Hedging-Cryptos-with-Bitcoin-Futures/newToQuantlet/Pynotebooks/CRIX' matched no files
# [NbConvertApp] WARNING | pattern '../data/QuantLet_to_parse/Hedging-Cryptos-with-Bitcoin-Futures/newToQuantlet/Pynotebooks/figures/figure' matched no files
# [NbConvertApp] WARNING | pattern 'calculation/crix_calculation.ipynb' matched no files
# [NbConvertApp] WARNING | pattern '12.ipynb' matched no files
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 525, in convert_notebooks
#     self.print_help()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 512, in print_help
#     print('\n'.join(self.emit_help(classes=classes)))
# BrokenPipeError: [Errno 32] Broken pipe
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 525, in convert_notebooks
#     self.print_help()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 512, in print_help
#     print('\n'.join(self.emit_help(classes=classes)))
# BrokenPipeError: [Errno 32] Broken pipe
# [NbConvertApp] WARNING | pattern '../data/QuantLet_to_parse/Hedging-Cryptos-with-Bitcoin-Futures/newToQuantlet/Pynotebooks/figures/intraday/figure' matched no files
# [NbConvertApp] WARNING | pattern '13.ipynb' matched no files
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
# [NbConvertApp] WARNING | pattern '../data/QuantLet_to_parse/Hedging-Cryptos-with-Bitcoin-Futures/newToQuantlet/Pynotebooks/.ipynb_checkpoints/Data' matched no files
# [NbConvertApp] WARNING | pattern 'Preprocessing-checkpoint.ipynb' matched no files
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 525, in convert_notebooks
#     self.print_help()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 512, in print_help
#     print('\n'.join(self.emit_help(classes=classes)))
# BrokenPipeError: [Errno 32] Broken pipe
# [NbConvertApp] WARNING | pattern '../data/QuantLet_to_parse/Hedging-Cryptos-with-Bitcoin-Futures/newToQuantlet/Pynotebooks/CRIX' matched no files
# [NbConvertApp] WARNING | pattern 'calculation/.ipynb_checkpoints/crix_calculation-checkpoint.ipynb' matched no files
# [NbConvertApp] Converting notebook ../data/QuantLet_to_parse/Hedging-Cryptos-with-Bitcoin-Futures/newToQuantlet/src/plots.ipynb to python
# [NbConvertApp] WARNING | pattern '../data/QuantLet_to_parse/Hedging-Cryptos-with-Bitcoin-Futures/newToQuantlet/Pynotebooks/tables/table' matched no files
# [NbConvertApp] WARNING | pattern '3.ipynb' matched no files
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 525, in convert_notebooks
#     self.print_help()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 512, in print_help
#     print('\n'.join(self.emit_help(classes=classes)))
# BrokenPipeError: [Errno 32] Broken pipe
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 525, in convert_notebooks
#     self.print_help()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 512, in print_help
#     print('\n'.join(self.emit_help(classes=classes)))
# BrokenPipeError: [Errno 32] Broken pipe
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 525, in convert_notebooks
#     self.print_help()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 512, in print_help
#     print('\n'.join(self.emit_help(classes=classes)))
# BrokenPipeError: [Errno 32] Broken pipe
# [NbConvertApp] Converting notebook ../data/QuantLet_to_parse/Hedging-Cryptos-with-Bitcoin-Futures/newToQuantlet/Pynotebooks/figures/intraday/get_calibratedCopulae.ipynb to python
# [NbConvertApp] Converting notebook ../data/QuantLet_to_parse/Hedging-Cryptos-with-Bitcoin-Futures/newToQuantlet/Pynotebooks/figures/intraday/select_copula.ipynb to python
# [NbConvertApp] WARNING | pattern '../data/QuantLet_to_parse/Hedging-Cryptos-with-Bitcoin-Futures/newToQuantlet/Pynotebooks/figures/Figure' matched no files
# [NbConvertApp] WARNING | pattern '3_4_5.ipynb' matched no files
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 525, in convert_notebooks
#     self.print_help()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 512, in print_help
#     print('\n'.join(self.emit_help(classes=classes)))
# BrokenPipeError: [Errno 32] Broken pipe
# [NbConvertApp] Converting notebook ../data/QuantLet_to_parse/Hedging-Cryptos-with-Bitcoin-Futures/newToQuantlet/src/run-Copy1.ipynb to python
# [NbConvertApp] WARNING | pattern '../data/QuantLet_to_parse/Hedging-Cryptos-with-Bitcoin-Futures/newToQuantlet/Pynotebooks/.ipynb_checkpoints/Download' matched no files
# [NbConvertApp] WARNING | pattern 'Tiingo' matched no files
# [NbConvertApp] WARNING | pattern 'Data-checkpoint.ipynb' matched no files
# [NbConvertApp] Converting notebook ../data/QuantLet_to_parse/Hedging-Cryptos-with-Bitcoin-Futures/newToQuantlet/src/.ipynb_checkpoints/run-Copy2-checkpoint.ipynb to python
# [NbConvertApp] Converting notebook ../data/QuantLet_to_parse/Hedging-Cryptos-with-Bitcoin-Futures/newToQuantlet/Pynotebooks/figures/intraday/gen_MSEs_LSVs.ipynb to python
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 525, in convert_notebooks
#     self.print_help()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 512, in print_help
#     print('\n'.join(self.emit_help(classes=classes)))
# BrokenPipeError: [Errno 32] Broken pipe
# [NbConvertApp] Converting notebook ../data/QuantLet_to_parse/Hedging-Cryptos-with-Bitcoin-Futures/newToQuantlet/src/run.ipynb to python
# [NbConvertApp] Converting notebook ../data/QuantLet_to_parse/Hedging-Cryptos-with-Bitcoin-Futures/newToQuantlet/src/run-Copy2.ipynb to python
# [NbConvertApp] WARNING | pattern '../data/QuantLet_to_parse/DEDA_Class_SS2018/DEDA_Class_SS2018_Regulation' matched no files
# [NbConvertApp] WARNING | pattern 'Risk' matched no files
# [NbConvertApp] WARNING | pattern 'for' matched no files
# [NbConvertApp] WARNING | pattern 'Cryptocurrencies/Filter' matched no files
# [NbConvertApp] WARNING | pattern 'sentiment.ipynb' matched no files
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 525, in convert_notebooks
#     self.print_help()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 512, in print_help
#     print('\n'.join(self.emit_help(classes=classes)))
# BrokenPipeError: [Errno 32] Broken pipe
# [NbConvertApp] Converting notebook ../data/QuantLet_to_parse/Hedging-Cryptos-with-Bitcoin-Futures/newToQuantlet/src/.ipynb_checkpoints/run-checkpoint.ipynb to python
# [NbConvertApp] WARNING | pattern '../data/QuantLet_to_parse/DEDA_Class_SS2018/DEDA_Class_SS2018_Regulation' matched no files
# [NbConvertApp] WARNING | pattern 'Risk' matched no files
# [NbConvertApp] WARNING | pattern 'for' matched no files
# [NbConvertApp] WARNING | pattern 'Cryptocurrencies/Crpto' matched no files
# [NbConvertApp] WARNING | pattern 'prices.ipynb' matched no files
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
# [NbConvertApp] WARNING | pattern '../data/QuantLet_to_parse/DEDA_Class_SS2018/DEDA_Class_SS2018_Regulation' matched no files
# [NbConvertApp] WARNING | pattern 'Risk' matched no files
# [NbConvertApp] WARNING | pattern 'for' matched no files
# [NbConvertApp] WARNING | pattern 'Cryptocurrencies/Legality' matched no files
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
# [NbConvertApp] WARNING | pattern 'map.ipynb' matched no files
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 525, in convert_notebooks
#     self.print_help()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 512, in print_help
#     print('\n'.join(self.emit_help(classes=classes)))
# BrokenPipeError: [Errno 32] Broken pipe
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 525, in convert_notebooks
#     self.print_help()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 512, in print_help
#     print('\n'.join(self.emit_help(classes=classes)))
# BrokenPipeError: [Errno 32] Broken pipe
# [NbConvertApp] WARNING | pattern '../data/QuantLet_to_parse/DEDA_Class_SS2018/DEDA_Class_SS2018_Regulation' matched no files
# [NbConvertApp] WARNING | pattern 'Risk' matched no files
# [NbConvertApp] WARNING | pattern 'for' matched no files
# [NbConvertApp] WARNING | pattern 'Cryptocurrencies/DEDA_Class_SS2018_Regrisk_sentiment_analysis.ipynb' matched no files
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
# [NbConvertApp] Converting notebook ../data/QuantLet_to_parse/Hedging-Cryptos-with-Bitcoin-Futures/newToQuantlet/src/.ipynb_checkpoints/run-Copy1-checkpoint.ipynb to python
# load_data_from_git.ipynb
# [NbConvertApp] WARNING | pattern '../data/QuantLet_to_parse/DEDA_Class_SS2018/DEDA_Class_SS2018_Regulation' matched no files
# [NbConvertApp] WARNING | pattern 'Risk' matched no files
# [NbConvertApp] WARNING | pattern 'for' matched no files
# [NbConvertApp] WARNING | pattern 'Cryptocurrencies/Web' matched no files
# [NbConvertApp] WARNING | pattern 'scraping.ipynb' matched no files
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 525, in convert_notebooks
#     self.print_help()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 512, in print_help
#     print('\n'.join(self.emit_help(classes=classes)))
# BrokenPipeError: [Errno 32] Broken pipe
# [NbConvertApp] Converting notebook ../data/QuantLet_to_parse/Deribit_inverse_BTC_options_hedging/Deribit_inverse_BTC_options_hedging.ipynb to python
# [NbConvertApp] Converting notebook ../data/QuantLet_to_parse/DEDA_class_2020SS/DEDA_2020_Sentiment-Analysis-of-Cryptocurrencies/DEDA_2020_Sentiment-Analysis-of-Cryptocurrencies.ipynb to python
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 525, in convert_notebooks
#     self.print_help()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 512, in print_help
#     print('\n'.join(self.emit_help(classes=classes)))
# BrokenPipeError: [Errno 32] Broken pipe
# parse_repos_to_df.ipynb
# parse_df_source_code.ipynb
# parse-folders.ipynb
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbformat/reader.py", line 18, in parse_json
#     nb_dict = json.loads(s, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/json/__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 541, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 506, in convert_single_notebook
#     output, resources = self.export_single_notebook(notebook_filename, resources, input_buffer=input_buffer)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 435, in export_single_notebook
#     output, resources = self.exporter.from_filename(notebook_filename, resources=resources)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 190, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 208, in from_file
#     return self.from_notebook_node(nbformat.read(file_stream, as_version=4), resources=resources, **kw)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbformat/__init__.py", line 170, in read
#     return reads(buf, as_version, capture_validation_error, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbformat/__init__.py", line 88, in reads
#     nb = reader.reads(s, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbformat/reader.py", line 72, in reads
#     nb_dict = parse_json(s, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbformat/reader.py", line 21, in parse_json
#     raise NotJSONError(("Notebook does not appear to be JSON: %r" % s)[:77] + "...") from e
# nbformat.reader.NotJSONError: Notebook does not appear to be JSON: '#Codes for Streaming (And Tokenizing)\n...
# [NbConvertApp] Converting notebook ../data/QuantLet_to_parse/Hedging-Cryptos-with-Bitcoin-Futures/newToQuantlet/src/.ipynb_checkpoints/plots-checkpoint.ipynb to python
# IV_implied_fair_premium_curves.ipynb
# Kou_Model_fitToPrice.ipynb
# [NbConvertApp] WARNING | pattern '../data/QuantLet_to_parse/UMAP/.ipynb_checkpoints/Umap' matched no files
# [NbConvertApp] WARNING | pattern 'on' matched no files
# [NbConvertApp] WARNING | pattern 'cryptopunks-checkpoint.ipynb' matched no files
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 525, in convert_notebooks
#     self.print_help()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 512, in print_help
#     print('\n'.join(self.emit_help(classes=classes)))
# BrokenPipeError: [Errno 32] Broken pipe
# [NbConvertApp] Converting notebook ../data/QuantLet_to_parse/Network-portfolio/Centrality_bar_chart_race/centrality_bar_chart_race.ipynb to python
# [NbConvertApp] WARNING | pattern '../data/QuantLet_to_parse/UMAP/Umap' matched no files
# [NbConvertApp] WARNING | pattern 'on' matched no files
# [NbConvertApp] WARNING | pattern 'cryptopunks.ipynb' matched no files
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
# ...
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 525, in convert_notebooks
#     self.print_help()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 512, in print_help
#     print('\n'.join(self.emit_help(classes=classes)))
# BrokenPipeError: [Errno 32] Broken pipe
# sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 525, in convert_notebooks
#     self.print_help()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 512, in print_help
#     print('\n'.join(self.emit_help(classes=classes)))
# BrokenPipeError: [Errno 32] Broken pipe
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 525, in convert_notebooks
#     self.print_help()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 512, in print_help
#     print('\n'.join(self.emit_help(classes=classes)))
# BrokenPipeError: [Errno 32] Broken pipe
# [NbConvertApp] Writing 3854 bytes to ../data/QuantLet_to_parse/DEDA_2022_NYCU/HW2/HW2_TracyZhou_0453946_YoubikeLocation/HW2_TracyZhou_0453946_YoubikeLocation.py
# [NbConvertApp] Converting notebook ../data/QuantLet_to_parse/DAI_digital_art_index/DAI_indicies/compute_index.ipynb to python
# [NbConvertApp] WARNING | pattern 'Chinese' matched no files
# [NbConvertApp] WARNING | pattern 'Symbol_CNN.ipynb' matched no files
# [NbConvertApp] Writing 1384 bytes to ../data/QuantLet_to_parse/DEDA_2022_NYCU/HW2/DEDA_Class_2022_311707016_JingXun/DEDA_Class_2022_311707016_JingXun.py
# [NbConvertApp] Writing 2858 bytes to ../data/QuantLet_to_parse/DEDA_2022_NYCU/Fraud_Detection/main.py
# [NbConvertApp] WARNING | pattern '../data/QuantLet_to_parse/SDA_2021_NUS/SDA_2021_NUS_Credit_Card_Default_Prediction/Feature_Engineering/Feature' matched no files
# [NbConvertApp] WARNING | pattern 'Selection.ipynb' matched no files
# [NbConvertApp] WARNING | pattern '../data/QuantLet_to_parse/SDA_2021_NUS/SDA_2021_NUS_Sentiment' matched no files
# [NbConvertApp] WARNING | pattern 'analysis' matched no files
# [NbConvertApp] WARNING | pattern 'of' matched no files
# [NbConvertApp] WARNING | pattern 'Chinese' matched no files
# [NbConvertApp] WARNING | pattern 'financial' matched no files
# [NbConvertApp] WARNING | pattern 'news/FE5225_Project_Step3_calculate_accuracy.ipynb' matched no files
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 525, in convert_notebooks
#     self.print_help()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 512, in print_help
#     print('\n'.join(self.emit_help(classes=classes)))
# BrokenPipeError: [Errno 32] Broken pipe
# [NbConvertApp] Writing 1996 bytes to ../data/QuantLet_to_parse/DEDA_2022_NYCU/HW2/DEDA_Class_2022_HW2_311707034_DavidJheng/DEDA_Class_2022_HW2_311707034_DavidJheng.py
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 525, in convert_notebooks
#     self.print_help()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 512, in print_help
#     print('\n'.join(self.emit_help(classes=classes)))
# BrokenPipeError: [Errno 32] Broken pipe
# [NbConvertApp] WARNING | pattern '../data/QuantLet_to_parse/SDA_2021_NUS/SDA_2021_NUS_Sentiment' matched no files
# [NbConvertApp] WARNING | pattern 'analysis' matched no files
# [NbConvertApp] WARNING | pattern 'of' matched no files
# [NbConvertApp] WARNING | pattern 'Chinese' matched no files
# [NbConvertApp] WARNING | pattern 'financial' matched no files
# [NbConvertApp] WARNING | pattern 'news/FE5225_Project_Step1_Sourcedata_to_txt.ipynb' matched no files
# [NbConvertApp] Converting notebook ../data/QuantLet_to_parse/SDA_2021_NUS/SDA_2021_NUS_Chinese_Symbol_CNN/MNIST to python
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 541, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
# [NbConvertApp] Writing 4038 bytes to ../data/QuantLet_to_parse/DEDA_2022_NYCU/HW1/DEDA_Class_2022_HW1_311707034_DavidJheng/DEDA_Class_2022_HW1_311707034_DavidJheng.py
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 506, in convert_single_notebook
#     output, resources = self.export_single_notebook(notebook_filename, resources, input_buffer=input_buffer)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 435, in export_single_notebook
#     output, resources = self.exporter.from_filename(notebook_filename, resources=resources)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 189, in from_filename
#     with io.open(filename, encoding='utf-8') as f:
# IsADirectoryError: [Errno 21] Is a directory: '../data/QuantLet_to_parse/SDA_2021_NUS/SDA_2021_NUS_Chinese_Symbol_CNN/MNIST'
# [NbConvertApp] Writing 9828 bytes to ../data/QuantLet_to_parse/DEDA_2022_NYCU/Fraud_Detection/Fraud_Detection_Model_Selection/Fraud_Detection_Model_Selection.py
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 525, in convert_notebooks
#     self.print_help()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 512, in print_help
#     print('\n'.join(self.emit_help(classes=classes)))
# BrokenPipeError: [Errno 32] Broken pipe
# [NbConvertApp] Writing 3519 bytes to ../data/QuantLet_to_parse/DEDA_2022_NYCU/HW5/DEDA_MobileCluster_Buris_311712023/DEDA_MobileCluster_Buris_311712023.py
# [NbConvertApp] Writing 3833 bytes to ../data/QuantLet_to_parse/DEDA_2022_NYCU/HW2/HW2_YoucefTahari_311709815_ubikes_ZhongshanDistrict/HW2_YoucefTahari_311709815_ubikes_ZhongshanDistrict.py
# [NbConvertApp] WARNING | pattern '../data/QuantLet_to_parse/DigitalEconomyDecisionAnalytics/DEDA_Hidden' matched no files
# [NbConvertApp] WARNING | pattern 'Markov' matched no files
# [NbConvertApp] WARNING | pattern 'Models/HMM' matched no files
# [NbConvertApp] WARNING | pattern 'Analysis' matched no files
# [NbConvertApp] WARNING | pattern 'of' matched no files
# [NbConvertApp] WARNING | pattern 'Heart' matched no files
# [NbConvertApp] WARNING | pattern 'Rate' matched no files
# [NbConvertApp] WARNING | pattern 'Data/HMM' matched no files
# [NbConvertApp] WARNING | pattern 'Analysis' matched no files
# [NbConvertApp] WARNING | pattern 'of' matched no files
# [NbConvertApp] WARNING | pattern 'Heart' matched no files
# [NbConvertApp] WARNING | pattern 'Rate' matched no files
# [NbConvertApp] WARNING | pattern 'Data.ipynb' matched no files
# Traceback (most recent call last):
#   File "/Users/izzy/anaconda3/envs/encode_code/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 525, in convert_notebooks
#     self.print_help()
#   File "/Users/izzy/anaconda3/envs/encode_code/lib/python3.9/site-packages/traitlets/config/application.py", line 512, in print_help
#     print('\n'.join(self.emit_help(classes=classes)))
# BrokenPipeError: [Errno 32] Broken pipe
# [NbConvertApp] Writing 3331 bytes to ../data/QuantLet_to_parse/DEDA_2022_NYCU/HW5/DEDA_BondCluster_Tracy_0453946/DEDA_BondCluster_Tracy_0453946.py
# [NbConvertApp] Converting notebook ../data/QuantLet_to_parse/Encode-the-Qode/Load-Quantlet-Data-From-Git/load_data_from_git.ipynb to python
# [NbConvertApp] Writing 2065 bytes to ../data/QuantLet_to_parse/DEDA_2022_NYCU/HW9/DEDA_Class_2022_410707007_Tzu-Ying/DEDA_Class_2022_410707007_Tzu-Ying.py
# [NbConvertApp] Converting notebook ../data/QuantLet_to_parse/Encode-the-Qode/Covert-Repos-To-DF/parse_repos_to_df.ipynb to python
# [NbConvertApp] Converting notebook ../data/QuantLet_to_parse/Encode-the-Qode/Parse-Quantlets-Source-Code/parse_df_source_code.ipynb to python
# [NbConvertApp] Converting notebook ../data/QuantLet_to_parse/Encode-the-Qode/Parse-Quantlets-Folders/parse-folders.ipynb to python
# [NbConvertApp] Converting notebook ../data/QuantLet_to_parse/IV_implied_fair_premium_curves/IV_implied_fair_premium_curves.ipynb to python
# [NbConvertApp] Writing 38 bytes to ../data/QuantLet_to_parse/p2pInterestRate/ratesPlots/.ipynb_checkpoints/ratePlots-checkpoint.py
# [NbConvertApp] Converting notebook ../data/QuantLet_to_parse/IV_implied_fair_premium_curves/Kou_Model_fitToPrice.ipynb to python
# [NbConvertApp] Writing 38 bytes to ../data/QuantLet_to_parse/p2pInterestRate/semiParametricModel/.ipynb_checkpoints/semiParametricModel-checkpoint.py
# [NbConvertApp] Writing 12710 bytes to ../data/QuantLet_to_parse/optimal_hedging_ratio_copula-1/Py_notebooks/Gumbel.py
# [NbConvertApp] Writing 12710 bytes to ../data/QuantLet_to_parse/optimal_hedging_ratio_copula-1/Py_notebooks/gumbel.py
# [NbConvertApp] Writing 3061 bytes to ../data/QuantLet_to_parse/UStatistics/ustatboot/ustatboot.py
# [NbConvertApp] Writing 2403 bytes to ../data/QuantLet_to_parse/p2pInterestRate/semiParametricModel/semiParametricModel.py
# [NbConvertApp] Writing 1807 bytes to ../data/QuantLet_to_parse/DAI_digital_art_index/DAI_dcs-t_score/score.py
# [NbConvertApp] Writing 2939 bytes to ../data/QuantLet_to_parse/UStatistics/ustatvar/ustatvar.py
# [NbConvertApp] Writing 10802 bytes to ../data/QuantLet_to_parse/DAI_digital_art_index/DAI_NFT_data/NFT_data_analysis.py
# [NbConvertApp] Writing 567 bytes to ../data/QuantLet_to_parse/p2pInterestRate/ratesPlots/ratePlots.py
# [NbConvertApp] Writing 3380 bytes to ../data/QuantLet_to_parse/DAI_digital_art_index/DAI_heckman_huberization/heckman_huberization.py
# [NbConvertApp] Writing 2320 bytes to ../data/QuantLet_to_parse/DAI_digital_art_index/DAI_quarterly_art_market/Quarterly_art_market_sales.py
# [NbConvertApp] Writing 5063 bytes to ../data/QuantLet_to_parse/DAI_digital_art_index/DAI_residual_analysis/residual_analysis.py
# [NbConvertApp] Writing 22193 bytes to ../data/QuantLet_to_parse/DAI_digital_art_index/DAI_autocorrelation_causality/autocorrelation_causality.py
# [NbConvertApp] Writing 9580 bytes to ../data/QuantLet_to_parse/DAI_digital_art_index/DAI_indicies/compute_index.py
# [NbConvertApp] Writing 933 bytes to ../data/QuantLet_to_parse/Encode-the-Qode/Load-Quantlet-Data-From-Git/load_data_from_git.py
# [NbConvertApp] Writing 3525 bytes to ../data/QuantLet_to_parse/Encode-the-Qode/Covert-Repos-To-DF/parse_repos_to_df.py
# [NbConvertApp] Writing 3037 bytes to ../data/QuantLet_to_parse/Encode-the-Qode/Parse-Quantlets-Source-Code/parse_df_source_code.py
# [NbConvertApp] Writing 3202 bytes to ../data/QuantLet_to_parse/Encode-the-Qode/Parse-Quantlets-Folders/parse-folders.py
# [NbConvertApp] Writing 7267 bytes to ../data/QuantLet_to_parse/IV_implied_fair_premium_curves/IV_implied_fair_premium_curves.py
# [NbConvertApp] Writing 10041 bytes to ../data/QuantLet_to_parse/IV_implied_fair_premium_curves/Kou_Model_fitToPrice.py
# [NbConvertApp] Writing 16622 bytes to ../data/QuantLet_to_parse/DAI_digital_art_index/DAI_indicies/simulation.py

# %%
Quantlets = []
repos = []
nw = 0
for i, (root, directories, files) in enumerate(os.walk(PATH_TO_PARSE)):

        m_file = [file for file in files if file.lower()=="metainfo.txt"] 
        q = {}
        q['folder_name'] = root
        

        if len(m_file)!=0:
            
            with open(f'{root}/{m_file[0]}', 'r') as meta:
                try:
                    metainfofile = yaml.safe_load(meta)#.readlines()
                except:
                    nw += 1
            q['metainfo_file'] = metainfofile
        else:
            q['metainfo_file'] = 'empty'

        code_files = [file for file in files if file.split('.')[-1] in FILE_TYPES] 
        
        if len(code_files)!=0:

            codes = []
            languages = []
            

            for code_i, c_file in enumerate(code_files):
                
                with open(f'{root}/{c_file}', 'rb') as code:
                    sc_file = code.readlines()
                
                language = c_file.split('.')[-1]

                if code_i == 0:
                    q['code_script'] = sc_file
                    q['type_script'] = language
                    q['script_name'] = c_file
                    repos.append(q)
                else:
                    extra_q = {}
                    extra_q['metainfo_file'] = q['metainfo_file']
                    extra_q['folder_name'] = q['folder_name']
                    extra_q['code_script'] = sc_file
                    extra_q['type_script'] = language
                    extra_q['script_name'] = c_file
                    repos.append(extra_q)
 
                #languages.append(language)  
                #    codes.append(sc_file)
                #q['code_script'] = codes
                #q['type_script'] = languages
        else: 
            q['code_script'] = 'empty'
            q['type_script'] = 'empty'

        repos.append(q)


repos_df = pd.DataFrame(repos)
repos_df = repos_df[~((repos_df.code_script=='empty')&(repos_df.metainfo_file=='empty')&(repos_df.type_script=='empty'))]
repos_df['q_name'] = repos_df.folder_name.str[26:]
repos_df = repos_df.drop_duplicates(['folder_name', 'script_name'])
repos_df
# Out:
#                                              folder_name  \
# 2      ../data/QuantLet_to_parse/BitcoinOptionTrading...
# 3      ../data/QuantLet_to_parse/BitcoinOptionTrading...
# 4      ../data/QuantLet_to_parse/BitcoinOptionTrading...
# 5      ../data/QuantLet_to_parse/BitcoinOptionTrading...
# 6      ../data/QuantLet_to_parse/BitcoinOptionTrading...
# ...                                                  ...
# 19844                    ../data/QuantLet_to_parse/UYCTR
# 19845                    ../data/QuantLet_to_parse/UYCTR
# 19846                    ../data/QuantLet_to_parse/UYCTR
# 19865  ../data/QuantLet_to_parse/Metis-Shapley/Additi...
# 19867  ../data/QuantLet_to_parse/Metis-Shapley/Boosti...
#
#                                            metainfo_file  \
# 2      {'Name of Quantlet': 'BitcoinOptionTrading', '...
# 3      {'Name of Quantlet': 'BitcoinOptionTrading', '...
# 4      {'Name of Quantlet': 'BitcoinOptionTrading', '...
# 5      {'Name of Quantlet': 'BitcoinOptionTrading', '...
# 6      {'Name of Quantlet': 'BitcoinOptionTrading', '...
# ...                                                  ...
# 19844  {'Name of Quantlet': 'UYCTReur', 'Published in...
# 19845  {'Name of Quantlet': 'UYCTReur', 'Published in...
# 19846  {'Name of Quantlet': 'UYCTReur', 'Published in...
# 19865  {'Name of Quantlet': 'Additive_Example', 'Publ...
# 19867  {'Name of Quantlet': 'Boosting_example', 'Publ...
#
#                                              code_script type_script  \
# 2      [b'import numpy as np\n', b'import pandas as p...          py
# 3      [b'import pandas as pd\n', b'import os\n', b'f...          py
# 4      [b'import dash\n', b'from dash.dependencies im...          py
# 5                   [b'# required for QuantLet Graph\n']          py
# 6      [b'import numpy as np\n', b'\n', b'from spd_tr...          py
# ...                                                  ...         ...
# 19844  [b'#------------------------------------------...           R
# 19845  [b'#------------------------------------------...           R
# 19846  [b'#------------------------------------------...           R
# 19865  [b'#!/usr/bin/env python\n', b'# coding: utf-8...          py
# 19867  [b'#!/usr/bin/env python\n', b'# coding: utf-8...          py
#
#                        script_name                                     q_name
# 2                   02-1_rnd_hd.py  BitcoinOptionTrading/BitcoinOptionTrading
# 3      01-1_rnd_data_processing.py  BitcoinOptionTrading/BitcoinOptionTrading
# 4                    04_explore.py  BitcoinOptionTrading/BitcoinOptionTrading
# 5          BitcoinOptionTrading.py  BitcoinOptionTrading/BitcoinOptionTrading
# 6         02-2_rnd_hd_corrected.py  BitcoinOptionTrading/BitcoinOptionTrading
# ...                            ...                                        ...
# 19844                     LRtest.R                                      UYCTR
# 19845                   UYCTReur.R                                      UYCTR
# 19846             Forecastingusd.R                                      UYCTR
# 19865          Additive_Example.py             Metis-Shapley/Additive_Example
# 19867          Boosting_example.py             Metis-Shapley/Boosting_example
#
# [8319 rows x 6 columns]

# %%
repos_df = repos_df.drop_duplicates(['folder_name', 'script_name'])
repos_df
# Out:
#                                              folder_name  \
# 2      ../data/QuantLet_to_parse/BitcoinOptionTrading...
# 3      ../data/QuantLet_to_parse/BitcoinOptionTrading...
# 4      ../data/QuantLet_to_parse/BitcoinOptionTrading...
# 5      ../data/QuantLet_to_parse/BitcoinOptionTrading...
# 6      ../data/QuantLet_to_parse/BitcoinOptionTrading...
# ...                                                  ...
# 19844                    ../data/QuantLet_to_parse/UYCTR
# 19845                    ../data/QuantLet_to_parse/UYCTR
# 19846                    ../data/QuantLet_to_parse/UYCTR
# 19865  ../data/QuantLet_to_parse/Metis-Shapley/Additi...
# 19867  ../data/QuantLet_to_parse/Metis-Shapley/Boosti...
#
#                                            metainfo_file  \
# 2      {'Name of Quantlet': 'BitcoinOptionTrading', '...
# 3      {'Name of Quantlet': 'BitcoinOptionTrading', '...
# 4      {'Name of Quantlet': 'BitcoinOptionTrading', '...
# 5      {'Name of Quantlet': 'BitcoinOptionTrading', '...
# 6      {'Name of Quantlet': 'BitcoinOptionTrading', '...
# ...                                                  ...
# 19844  {'Name of Quantlet': 'UYCTReur', 'Published in...
# 19845  {'Name of Quantlet': 'UYCTReur', 'Published in...
# 19846  {'Name of Quantlet': 'UYCTReur', 'Published in...
# 19865  {'Name of Quantlet': 'Additive_Example', 'Publ...
# 19867  {'Name of Quantlet': 'Boosting_example', 'Publ...
#
#                                              code_script type_script  \
# 2      [b'import numpy as np\n', b'import pandas as p...          py
# 3      [b'import pandas as pd\n', b'import os\n', b'f...          py
# 4      [b'import dash\n', b'from dash.dependencies im...          py
# 5                   [b'# required for QuantLet Graph\n']          py
# 6      [b'import numpy as np\n', b'\n', b'from spd_tr...          py
# ...                                                  ...         ...
# 19844  [b'#------------------------------------------...           R
# 19845  [b'#------------------------------------------...           R
# 19846  [b'#------------------------------------------...           R
# 19865  [b'#!/usr/bin/env python\n', b'# coding: utf-8...          py
# 19867  [b'#!/usr/bin/env python\n', b'# coding: utf-8...          py
#
#                        script_name                                     q_name
# 2                   02-1_rnd_hd.py  BitcoinOptionTrading/BitcoinOptionTrading
# 3      01-1_rnd_data_processing.py  BitcoinOptionTrading/BitcoinOptionTrading
# 4                    04_explore.py  BitcoinOptionTrading/BitcoinOptionTrading
# 5          BitcoinOptionTrading.py  BitcoinOptionTrading/BitcoinOptionTrading
# 6         02-2_rnd_hd_corrected.py  BitcoinOptionTrading/BitcoinOptionTrading
# ...                            ...                                        ...
# 19844                     LRtest.R                                      UYCTR
# 19845                   UYCTReur.R                                      UYCTR
# 19846             Forecastingusd.R                                      UYCTR
# 19865          Additive_Example.py             Metis-Shapley/Additive_Example
# 19867          Boosting_example.py             Metis-Shapley/Boosting_example
#
# [8319 rows x 6 columns]

# %%
#!pip install pandas==1.3.5 # for comaparability woth colab

# %%
import pickle 
with open('../data/Parsed_Qs_20230126.pkl', 'wb') as file:
    pickle.dump(repos_df, file)

# %%
repos_df.to_csv('../data/Parsed_Qs_20230126.csv', index=False)
